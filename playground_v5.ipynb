# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sub21_normal.csv')
df
# Out:
#       id  target   O2_1   O2_2  O2_3  O2_4  O2_5  O2_6  O2_7  NH4_1  ...  \
# 0      0    8.59  7.500  9.000     0     0     0     0     0      0  ...
# 1      0    8.21  3.710  5.420     0     0     0     0     0      0  ...
# 2      0    8.39  8.700  8.100     0     0     0     0     0      0  ...
# 3      0    8.07  8.050  8.650     0     0     0     0     0      0  ...
# 4      0    8.12  9.000  9.000     0     0     0     0     0      0  ...
# ...   ..     ...    ...    ...   ...   ...   ...   ...   ...    ...  ...
# 3038   0    8.65  8.367  8.760     0     0     0     0     0      0  ...
# 3039   0    8.08  6.250  8.300     0     0     0     0     0      0  ...
# 3040   0    8.09  6.630  6.630     0     0     0     0     0      0  ...
# 3041   0    9.95  8.367  8.433     0     0     0     0     0      0  ...
# 3042   0    8.51  8.500  8.100     0     0     0     0     0      0  ...
#
#       NO3_5  NO3_6  NO3_7  BOD5_1  BOD5_2  BOD5_3  BOD5_4  BOD5_5  BOD5_6  \
# ...

# %%
df.target = df.target.clip(7, 16)

# %%
len(df[df['target']==7].index.to_numpy())
# Out:
# 163

# %%
# 130 (1.30) -> 150 (1.31) -> 120 (clip 16 instead of 20) (1.31)

# %%
drop_index = np.random.choice(df[df['target']==7].index.to_numpy(), 150, replace=False)
df.loc[drop_index]
# Out:
#       id  target  O2_1   O2_2  O2_3  O2_4  O2_5  O2_6  O2_7  NH4_1  ...  \
# 1691   0     7.0  4.20  4.725     0     0     0     0     0      0  ...
# 154    0     7.0  6.10  7.500     0     0     0     0     0      0  ...
# 1570   0     7.0  7.35  6.950     0     0     0     0     0      0  ...
# 2112   0     7.0  8.10  7.800     0     0     0     0     0      0  ...
# 2139   0     7.0  7.40  8.500     0     0     0     0     0      0  ...
# ...   ..     ...   ...    ...   ...   ...   ...   ...   ...    ...  ...
# 2349   0     7.0  5.70  8.400     0     0     0     0     0      0  ...
# 1752   0     7.0  7.25  7.400     0     0     0     0     0      0  ...
# 2507   0     7.0  7.10  6.400     0     0     0     0     0      0  ...
# 510    0     7.0  9.70  8.900     0     0     0     0     0      0  ...
# 2250   0     7.0  7.10  6.900     0     0     0     0     0      0  ...
#
#       NO3_5  NO3_6  NO3_7  BOD5_1  BOD5_2  BOD5_3  BOD5_4  BOD5_5  BOD5_6  \
# ...

# %%
df = df.drop(drop_index)
df.shape
# Out:
# (2893, 37)

# %%
df.to_csv('sub23-aggressive-drop.csv', index=False)
